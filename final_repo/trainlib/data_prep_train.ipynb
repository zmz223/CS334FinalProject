# %%
import pandas as pd
import os
from tableone import TableOne

# %%
meta = pd.read_csv('/home/zzaiman/local/physionet.org/files/mimic-cxr-jpg/2.0.0/mimic-cxr-2.0.0-metadata.csv')

# %%
meta.shape
# Out:
# (377110, 12)

# %%
meta.head()
# Out:
#                                        dicom_id  subject_id  study_id  \
# 0  02aa804e-bde0afdd-112c0b34-7bc16630-4e384014    10000032  50414267
# 1  174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962    10000032  50414267
# 2  2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab    10000032  53189527
# 3  e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c    10000032  53189527
# 4  68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714    10000032  53911762
#
#   PerformedProcedureStepDescription ViewPosition  Rows  Columns  StudyDate  \
# 0                CHEST (PA AND LAT)           PA  3056     2544   21800506
# 1                CHEST (PA AND LAT)      LATERAL  3056     2544   21800506
# 2                CHEST (PA AND LAT)           PA  3056     2544   21800626
# 3                CHEST (PA AND LAT)      LATERAL  3056     2544   21800626
# 4               CHEST (PORTABLE AP)           AP  2705     2539   21800723
#
#     StudyTime ProcedureCodeSequence_CodeMeaning ViewCodeSequence_CodeMeaning  \
# 0  213014.531                CHEST (PA AND LAT)             postero-anterior
# 1  213014.531                CHEST (PA AND LAT)                      lateral
# 2  165500.312                CHEST (PA AND LAT)             postero-anterior
# 3  165500.312                CHEST (PA AND LAT)                      lateral
# 4   80556.875               CHEST (PORTABLE AP)             antero-posterior
#
#   PatientOrientationCodeSequence_CodeMeaning
# 0                                      Erect
# 1                                      Erect
# 2                                      Erect
# 3                                      Erect
# 4                                        NaN

# %%
# Filter for frontal view positions.
meta = meta[meta['ViewPosition'].isin(['AP', 'PA'])].reset_index(drop=True)

# %%
meta.shape
# Out:
# (243334, 12)

# %%
split = pd.read_csv('/home/zzaiman/local/physionet.org/files/mimic-cxr-jpg/2.0.0/mimic-cxr-2.0.0-split.csv')

# %%
split = split.merge(meta, on=['dicom_id', 'subject_id', 'study_id'])

# %%
split.shape
# Out:
# (243334, 13)

# %%
split.head()
# Out:
#                                        dicom_id  study_id  subject_id  split  \
# 0  02aa804e-bde0afdd-112c0b34-7bc16630-4e384014  50414267    10000032  train
# 1  2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab  53189527    10000032  train
# 2  68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714  53911762    10000032  train
# 3  fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818  53911762    10000032  train
# 4  ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c  56699142    10000032  train
#
#   PerformedProcedureStepDescription ViewPosition  Rows  Columns  StudyDate  \
# 0                CHEST (PA AND LAT)           PA  3056     2544   21800506
# 1                CHEST (PA AND LAT)           PA  3056     2544   21800626
# 2               CHEST (PORTABLE AP)           AP  2705     2539   21800723
# 3               CHEST (PORTABLE AP)           AP  2906     2258   21800723
# 4               CHEST (PORTABLE AP)           AP  3056     2544   21800805
#
#     StudyTime ProcedureCodeSequence_CodeMeaning ViewCodeSequence_CodeMeaning  \
# 0  213014.531                CHEST (PA AND LAT)             postero-anterior
# 1  165500.312                CHEST (PA AND LAT)             postero-anterior
# 2   80556.875               CHEST (PORTABLE AP)             antero-posterior
# 3   80556.875               CHEST (PORTABLE AP)             antero-posterior
# 4  234424.765               CHEST (PORTABLE AP)             antero-posterior
#
#   PatientOrientationCodeSequence_CodeMeaning
# 0                                      Erect
# 1                                      Erect
# 2                                        NaN
# 3                                      Erect
# 4                                        NaN

# %%
split['split'].value_counts()
# Out:
# train       237972
# test          3403
# validate      1959
# Name: split, dtype: int64

# %%
labels = pd.read_csv('/home/zzaiman/local/physionet.org/files/mimic-cxr-jpg/2.0.0/mimic-cxr-2.0.0-chexpert.csv')

# %%
labels.shape
# Out:
# (227827, 16)

# %%
labels.head()
# Out:
#    subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0    10000032  50414267          NaN           NaN            NaN    NaN
# 1    10000032  53189527          NaN           NaN            NaN    NaN
# 2    10000032  53911762          NaN           NaN            NaN    NaN
# 3    10000032  56699142          NaN           NaN            NaN    NaN
# 4    10000764  57375967          NaN           NaN            1.0    NaN
#
#    Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  \
# 0                         NaN       NaN          NaN           NaN
# 1                         NaN       NaN          NaN           NaN
# 2                         NaN       NaN          NaN           NaN
# 3                         NaN       NaN          NaN           NaN
# 4                         NaN       NaN          NaN           NaN
#
#    No Finding  Pleural Effusion  Pleural Other  Pneumonia  Pneumothorax  \
# 0         1.0               NaN            NaN        NaN           NaN
# 1         1.0               NaN            NaN        NaN           NaN
# 2         1.0               NaN            NaN        NaN           NaN
# 3         1.0               NaN            NaN        NaN           NaN
# 4         NaN               NaN            NaN       -1.0           NaN
#
#    Support Devices
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
labels.nunique()
# Out:
# subject_id                     65379
# study_id                      227827
# Atelectasis                        3
# Cardiomegaly                       3
# Consolidation                      3
# Edema                              3
# Enlarged Cardiomediastinum         3
# Fracture                           3
# Lung Lesion                        3
# Lung Opacity                       3
# No Finding                         1
# Pleural Effusion                   3
# Pleural Other                      3
# Pneumonia                          3
# Pneumothorax                       3
# Support Devices                    3
# dtype: int64

# %%
# Merge available labels with train test splits.
avail = labels.merge(split)

# %%
avail.shape
# Out:
# (243324, 27)

# %%
avail.head()
# Out:
#    subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0    10000032  50414267          NaN           NaN            NaN    NaN
# 1    10000032  53189527          NaN           NaN            NaN    NaN
# 2    10000032  53911762          NaN           NaN            NaN    NaN
# 3    10000032  53911762          NaN           NaN            NaN    NaN
# 4    10000032  56699142          NaN           NaN            NaN    NaN
#
#    Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  ...  \
# 0                         NaN       NaN          NaN           NaN  ...
# 1                         NaN       NaN          NaN           NaN  ...
# 2                         NaN       NaN          NaN           NaN  ...
# 3                         NaN       NaN          NaN           NaN  ...
# 4                         NaN       NaN          NaN           NaN  ...
#
#    split  PerformedProcedureStepDescription  ViewPosition  Rows  Columns  \
# 0  train                 CHEST (PA AND LAT)            PA  3056     2544
# 1  train                 CHEST (PA AND LAT)            PA  3056     2544
# 2  train                CHEST (PORTABLE AP)            AP  2705     2539
# 3  train                CHEST (PORTABLE AP)            AP  2906     2258
# 4  train                CHEST (PORTABLE AP)            AP  3056     2544
#
#    StudyDate   StudyTime ProcedureCodeSequence_CodeMeaning  \
# 0   21800506  213014.531                CHEST (PA AND LAT)
# 1   21800626  165500.312                CHEST (PA AND LAT)
# 2   21800723   80556.875               CHEST (PORTABLE AP)
# 3   21800723   80556.875               CHEST (PORTABLE AP)
# 4   21800805  234424.765               CHEST (PORTABLE AP)
#
#   ViewCodeSequence_CodeMeaning PatientOrientationCodeSequence_CodeMeaning
# 0             postero-anterior                                      Erect
# 1             postero-anterior                                      Erect
# 2             antero-posterior                                        NaN
# 3             antero-posterior                                      Erect
# 4             antero-posterior                                        NaN
#
# [5 rows x 27 columns]

# %%
# Create path to dicom relative to physionet.
avail['path'] = avail.apply(lambda x: f'p{str(x["subject_id"])[:2]}/p{str(x["subject_id"])}/s{str(x["study_id"])}/{str(x["dicom_id"])}.jpg', axis=1)

# %%
avail['path'].iloc[0]
# Out:
# 'p10/p10000032/s50414267/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.jpg'

# %%
# Verify that paths exist.
# Must append base path in training code.
for path in avail['path'].values:
    assert os.path.exists(os.path.join('/home/zzaiman/local/physionet.org/files/mimic-cxr-jpg/2.0.0/files/', path))

# %%
avail = avail.fillna(0)
avail = avail.replace(-1, 0)

# %%
dest='/home/zzaiman/local/processed_splits'

# %%
train = avail[avail['split'] == 'train']
test = avail[avail['split'] == 'test']
valid = avail[avail['split'] == 'validate']

# %%
train.shape
# Out:
# (237962, 28)

# %%
valid.shape
# Out:
# (1959, 28)

# %%
test.shape
# Out:
# (3403, 28)

# %%
train.to_csv(os.path.join(dest, 'train.csv'), index=False)
valid.to_csv(os.path.join(dest, 'valid.csv'), index=False)
test.to_csv(os.path.join(dest, 'test.csv'), index=False)

# %%
train_table = TableOne(train, columns=list(labels)[2:], missing=False)
valid_table = TableOne(valid, columns=list(labels)[2:], missing=False)
test_table = TableOne(test, columns=list(labels)[2:], missing=False)

# %%
train_table.to_csv('train_imb.csv')

# %%
valid_table
# Out:
#                                            Overall
# n                                             1959
# Atelectasis, n (%)                0.0  1564 (79.8)
#                                   1.0   395 (20.2)
# Cardiomegaly, n (%)               0.0  1557 (79.5)
#                                   1.0   402 (20.5)
# Consolidation, n (%)              0.0  1876 (95.8)
#                                   1.0     83 (4.2)
# Edema, n (%)                      0.0  1695 (86.5)
#                                   1.0   264 (13.5)
# Enlarged Cardiomediastinum, n (%) 0.0  1901 (97.0)
#                                   1.0     58 (3.0)
# Fracture, n (%)                   0.0  1941 (99.1)
#                                   1.0     18 (0.9)
# Lung Lesion, n (%)                0.0  1884 (96.2)
#                                   1.0     75 (3.8)
# Lung Opacity, n (%)               0.0  1543 (78.8)
#                                   1.0   416 (21.2)
# No Finding, n (%)                 0.0  1322 (67.5)
#                                   1.0   637 (32.5)
# Pleural Effusion, n (%)           0.0  1454 (74.2)
#                                   1.0   505 (25.8)
# Pleural Other, n (%)              0.0  1944 (99.2)
#                                   1.0     15 (0.8)
# Pneumonia, n (%)                  0.0  1836 (93.7)
#                                   1.0    123 (6.3)
# Pneumothorax, n (%)               0.0  1878 (95.9)
#                                   1.0     81 (4.1)
# Support Devices, n (%)            0.0  1324 (67.6)
#                                   1.0   635 (32.4)

# %%
test_table
# Out:
#                                            Overall
# n                                             3403
# Atelectasis, n (%)                0.0  2639 (77.5)
#                                   1.0   764 (22.5)
# Cardiomegaly, n (%)               0.0  2507 (73.7)
#                                   1.0   896 (26.3)
# Consolidation, n (%)              0.0  3192 (93.8)
#                                   1.0    211 (6.2)
# Edema, n (%)                      0.0  2677 (78.7)
#                                   1.0   726 (21.3)
# Enlarged Cardiomediastinum, n (%) 0.0  3260 (95.8)
#                                   1.0    143 (4.2)
# Fracture, n (%)                   0.0  3316 (97.4)
#                                   1.0     87 (2.6)
# Lung Lesion, n (%)                0.0  3282 (96.4)
#                                   1.0    121 (3.6)
# Lung Opacity, n (%)               0.0  2305 (67.7)
#                                   1.0  1098 (32.3)
# No Finding, n (%)                 0.0  2809 (82.5)
#                                   1.0   594 (17.5)
# Pleural Effusion, n (%)           0.0  2308 (67.8)
#                                   1.0  1095 (32.2)
# Pleural Other, n (%)              0.0  3340 (98.1)
#                                   1.0     63 (1.9)
# Pneumonia, n (%)                  0.0  3061 (90.0)
#                                   1.0   342 (10.0)
# Pneumothorax, n (%)               0.0  3295 (96.8)
#                                   1.0    108 (3.2)
# Support Devices, n (%)            0.0  2192 (64.4)
#                                   1.0  1211 (35.6)

# %%
full = pd.concat([train, valid, test], axis=0)
full_table = TableOne(full, columns=list(labels)[2:], missing=False)

# %%
full_table.to_latex('full_table.ltx')
